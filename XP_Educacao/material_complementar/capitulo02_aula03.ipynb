# %%
# Erros de Sintaxe

# %%
x = 10
y = 5
print(x + y)
# Out:
# 15

# %%
if x == 3:
    print('x é igual à 3')
    print('fim do bloco de código')

# %%
# Erros em Tempo de Execução

# %%
a = 1000
print(a)
b = 0
print(b)
c = a / b
print(c)
# Out:
# 1000
# 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-17-a2b634f0145b> in <module>()
#       3 b = 0
#       4 print(b)
# ----> 5 c = a / b
#       6 print(c)
#
# ZeroDivisionError: division by zero

# %%
cidade = 'Belo Horizonte'
print(cidade)
estado = 'Minas Gerais'
print(estado)
print(cidade, estado, pais)
# Out:
# Belo Horizonte
# Minas Gerais
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-5bdbd5fd6a21> in <module>()
#       3 estado = 'Minas Gerais'
#       4 print(estado)
# ----> 5 print(cidade, estado, pais)
#
# NameError: name 'pais' is not defined

# %%
cidade = 'Belo Horizonte'
print(cidade)
1estado = 'Minas Gerais'
print(1estado)
print(cidade, 1estado, pais)
# Out:
#   File "<ipython-input-22-9f7f4b1fb86c>", line 3
#     1estado = 'Minas Gerais'
#           ^
# SyntaxError: invalid syntax

# %%
# Erros Lógicosb

# %%
x = 5.0
y = 7.0
z = 12.0
media = x + y + z / 3
#media = 5 + 7 + 12 / 3
#media = 5 + 7 + 4 = 16
print(media)
# Out:
# 16.0

# %%
x = 5.0
y = 7.0
z = 12.0
media = (x + y + z) / 3
print(media)
# Out:
# 8.0
