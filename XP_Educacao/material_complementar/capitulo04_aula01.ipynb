# %% [markdown]
# # Capítulo 04 - Fluxos de Controle em Python

# %% [markdown]
# ## Aula 01 - Estruturas Condicionais
# - Estrutura Condicional `if`
# - Estrutura Condicional `if – else`
# - Estrutura Condicional `if – elif – else`

# %% [markdown]
# ### Estrutura Condicional `if`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
y = 0
a = 0
b = 0
c = 0
x = 5
if x > 10:
    y = x + 99
    a = x * 2
    b = x + 2
    c = x ** 2
print(y, a, b, c)
# Out:
# 0 0 7 25

# %%
# Exemplo em que a condição é verdadeira
idade = 35
if idade >= 18: 
    print('Idade suficiente para CNH!')
print('Fim do programa')
# Out:
# Idade suficiente para CNH!
# Fim do programa

# %%
# Exemplo em que a condição é falsa
idade = 15
if idade >= 18: 
    print('Idade suficiente para CNH!')
print('Fim do programa')
# Out:
# Fim do programa

# %%
# Verifica se uma pessoa está apta para se aposentar
idade = 20
tempo_contrib = 35
if idade >= 65 or tempo_contrib >= 35: 
    print('Habilitado para solicitar aposentadoria!')
# Out:
# Habilitado para solicitar aposentadoria!

# %%
# Verifica se uma pessoa não está apta a se aposentar
idade = 70
tempo_contrib = 20

if idade < 65 and tempo_contrib < 35: 
    print('Não habilitado para solicitar aposentadoria!')

# %% [markdown]
# ### Estrutura Condicional `if - else`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = 3
y = 0
if x > 10:
    print(f'O valor de {x} > 10')
    y = x * 2
else:
    print(f'O valor de {x} <= 10')
    y = x ** 2
print(y)
# Out:
# O valor de 3 <= 10
# 9

# %%
# Exemplo em que a condição é verdadeira
idade = 35

if idade >= 18: 
    print('Idade suficiente para CNH!')
else:
    print('Idade não suficiente para CNH!')
# Out:
# Idade suficiente para CNH!

# %%
# Exemplo em que a condição é falsa
idade = 15

if idade >= 18: 
    print('Idade suficiente para CNH!')
else:
    print('Idade não suficiente para CNH!')
# Out:
# Idade não suficiente para CNH!

# %%
# Verifica se uma pessoa está apta para se aposentar
idade = 20
tempo_contrib = 20

if idade >= 65 or tempo_contrib >= 35: 
    print('Habilitado para solicitar aposentadoria!')
else:
    print('Não habilitado para solicitar aposentadoria!')
# Out:
# Não habilitado para solicitar aposentadoria!

# %%
# Verifica se uma pessoa está apta para se aposentar
idade = 0
tempo_contrib = 0

if idade >= 65:
    print('Habilitado para aposentadoria por idade!')
else:
    print('Não habilitado para solicitar aposentadoria por idade!')

if tempo_contrib >= 35: 
    print('Habilitado para aposentadoria por tempo de contribuição!')
else:
    print('Não habilitado para solicitar aposentadoria por contribuição!')
# Out:
# Não habilitado para solicitar aposentadoria por idade!
# Não habilitado para solicitar aposentadoria por contribuição!

# %% [markdown]
# ### Estrutura Condicional `if - elif - else`

# %% [markdown]
# Considerem o problema de classificar a faixa etária de uma pessoa, segundo a sua idade :
# - Criança: menor que 12 anos.
# - Adolescente: maior ou igual que 12 anos e menor que 18 anos.
# - Adulto: maior ou igual que 18 anos e menor que 60 anos.
# - Idoso: maior ou igual que 60 anos

# %%
# Resolvendo o problema com apenas if - else
# idade 22 anos, faixa etária: Adulto
idade = 5

if idade < 12:
    faixa_etaria = 'Criança'
else:
    if idade < 18:
        faixa_etaria = 'Adolescente'
    else:
        if idade < 60:
            faixa_etaria = 'Adulto'
        else:
            faixa_etaria = 'Idoso'
print('Faixa Etária: ', faixa_etaria)
# Out:
# Faixa Etária:  Criança

# %%
# Podemos resolver o mesmo problema utilizando a estrutura if - elif -else
# if <expressão 1>:
#     <bloco de código se a expressão 1 é verdadeira>
# elif <expressão 2>:
#     <bloco de código se a expressão 2 é verdadeira>
# elif <expressão 3>:
#     <bloco de código se a expressão 2 é verdadeira>
# else:
#     <bloco de código se nenhuma expressão é verdadeira>

# %%
idade = 75

if idade < 12:
    faixa_etaria = 'Criança'
elif idade < 18:
    faixa_etaria = 'Adolescente'
elif idade < 60:
    faixa_etaria = 'Adulto'
else:
    faixa_etaria = 'Idoso'
print('Faixa Etária: ', faixa_etaria)
# Out:
# Faixa Etária:  Idoso
