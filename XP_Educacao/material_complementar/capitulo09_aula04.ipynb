# %% [markdown]
# # Capítulo 09 - Recursos Úteis da Linguagem

# %% [markdown]
# ## Aula 04 - Atribuição Condicional
#
# Sintaxe:
#
# ```python
# valor_se_verdadeiro if condicao else valor_se_falso
# ```

# %%
nome = 'casa'
if len(nome) > 5:
    var = 100
else:
    var = 0
print('O valor de var é:', var)
# Out:
# O valor de var é: 0

# %%
nome = 'casa'
var = 100 if len(nome) > 5 else 0
print('O valor de var é:', var)
# Out:
#   File "<ipython-input-5-e7df186cab90>", line 2
#     var = 100 if len(nome) > 5
#                               ^
# SyntaxError: invalid syntax
